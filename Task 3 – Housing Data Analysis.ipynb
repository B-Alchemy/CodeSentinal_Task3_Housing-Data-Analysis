# %% [markdown]
# ***"Dataset: kc_house_data.csv"***

# %% [markdown]
# Task 3 Requirements Recap
#
# Correlation matrix heatmap
#
# Top 5 most frequent values in selected columns
#
# Distribution plots (histograms, boxplots)
#
# Tools: pandas, seaborn, matplotlib

# %% [markdown]
# **Import Libraries**

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="whitegrid")

# %% [markdown]
# **Load Dataset**

# %%
df = pd.read_csv("kc_house_data.csv")
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7      1180.0              0
# 1      7242     2.0           0     0  ...      7      2170.0            400
# 2     10000     1.0           0     0  ...      6       770.0              0
# 3      5000     1.0           0     0  ...      7      1050.0            910
# 4      8080     1.0           0     0  ...      8      1680.0              0
#
# ...

# %% [markdown]
# **Correlation Matrix Heatmap**

# %%
# Keep only numeric columns
numeric_df = df.select_dtypes(include=['number'])

plt.figure(figsize=(12,8))
sns.heatmap(numeric_df.corr(), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Matrix Heatmap")
plt.show()

# %% [markdown]
# **Top 5 Most Frequent Values in Selected Columns**

# %%
for col in ['zipcode', 'bedrooms']:
    if col in df.columns:
        print(f"\nTop 5 most frequent values in {col}:")
        print(df[col].value_counts().head(5))
# Out:
# Top 5 most frequent values in zipcode:
# zipcode
# 98103    602
# 98038    590
# 98115    583
# 98052    574
# 98117    553
# Name: count, dtype: int64
#
# Top 5 most frequent values in bedrooms:
# bedrooms
# 3    9824
# 4    6882
# 2    2760
# 5    1601
# 6     272
# Name: count, dtype: int64

# %% [markdown]
# **Distribution Plots – Histograms**

# %%
plt.figure(figsize=(8,5))
sns.histplot(df['price'], bins=50, kde=True)
plt.title("Price Distribution")
plt.xlabel("Price")
plt.show()
# Out:
# C:\Users\Administrator\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# **Distribution Plots – Boxplots**

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x='bedrooms', y='price', data=df)
plt.title("Price vs Bedrooms")
plt.show()

# %% [markdown]
# Summary – Housing Data Analysis
# - The correlation matrix shows that `sqft_living` and `grade` are most strongly correlated with price.
# - The most common number of bedrooms is 3, and certain zip codes dominate property listings.
# - Price distribution is right-skewed, with more lower-priced houses and fewer high-priced ones.
# - Houses with more bedrooms tend to have higher prices, but extremely large bedroom counts may lower price due to outdated design or non-standard layouts.
